# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import numpy as np
from sklearn.feature_selection import mutual_info_regression
from sklearn.linear_model import LassoCV

# %%
df = pd.read_csv('/kaggle/input/salesprediction/Advertising.csv')
df.head()
# Out:
#    index     TV  Radio  Newspaper  Sales
# 0      1  230.1   37.8       69.2   22.1
# 1      2   44.5   39.3       45.1   10.4
# 2      3   17.2   45.9       69.3    9.3
# 3      4  151.5   41.3       58.5   18.5
# 4      5  180.8   10.8       58.4   12.9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   index      200 non-null    int64
#  1   TV         200 non-null    float64
#  2   Radio      200 non-null    float64
#  3   Newspaper  200 non-null    float64
#  4   Sales      200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
df.isnull().sum()
# Out:
# index        0
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (200, 5)

# %%
numerical_summary = df.describe().transpose()
palette = sns.color_palette("viridis", as_cmap=True)
numerical_summary.style.background_gradient(cmap=palette)
# Out:
# <style type="text/css">
# #T_5253b_row0_col0, #T_5253b_row1_col0, #T_5253b_row2_col0, #T_5253b_row2_col3, #T_5253b_row2_col4, #T_5253b_row3_col0, #T_5253b_row4_col0, #T_5253b_row4_col1, #T_5253b_row4_col2, #T_5253b_row4_col5, #T_5253b_row4_col6, #T_5253b_row4_col7 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_5253b_row0_col1 {
#   background-color: #2fb47c;
#   color: #f1f1f1;
# }
# #T_5253b_row0_col2 {
#   background-color: #31b57b;
#   color: #f1f1f1;
# }
# #T_5253b_row0_col3 {
#   background-color: #28ae80;
#   color: #f1f1f1;
# }
# #T_5253b_row0_col4 {
#   background-color: #2ab07f;
#   color: #f1f1f1;
# }
# #T_5253b_row0_col5 {
#   background-color: #2cb17e;
#   color: #f1f1f1;
# }
# #T_5253b_row0_col6 {
#   background-color: #32b67a;
#   color: #f1f1f1;
# }
# #T_5253b_row0_col7 {
#   background-color: #2db27d;
#   color: #f1f1f1;
# }
# #T_5253b_row1_col1, #T_5253b_row1_col2, #T_5253b_row1_col4, #T_5253b_row1_col5, #T_5253b_row1_col6, #T_5253b_row1_col7, #T_5253b_row4_col3 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_5253b_row1_col3 {
#   background-color: #26818e;
#   color: #f1f1f1;
# }
# #T_5253b_row2_col1 {
#   background-color: #481a6c;
#   color: #f1f1f1;
# }
# #T_5253b_row2_col2 {
#   background-color: #472a7a;
#   color: #f1f1f1;
# }
# #T_5253b_row2_col5 {
#   background-color: #481b6d;
#   color: #f1f1f1;
# }
# #T_5253b_row2_col6, #T_5253b_row3_col5 {
#   background-color: #482374;
#   color: #f1f1f1;
# }
# #T_5253b_row2_col7 {
#   background-color: #481f70;
#   color: #f1f1f1;
# }
# #T_5253b_row3_col1 {
#   background-color: #472c7a;
#   color: #f1f1f1;
# }
# #T_5253b_row3_col2 {
#   background-color: #404588;
#   color: #f1f1f1;
# }
# #T_5253b_row3_col3 {
#   background-color: #423f85;
#   color: #f1f1f1;
# }
# #T_5253b_row3_col4 {
#   background-color: #471164;
#   color: #f1f1f1;
# }
# #T_5253b_row3_col6 {
#   background-color: #46307e;
#   color: #f1f1f1;
# }
# #T_5253b_row3_col7 {
#   background-color: #32658e;
#   color: #f1f1f1;
# }
# #T_5253b_row4_col4 {
#   background-color: #440256;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_5253b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5253b_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_5253b_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_5253b_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_5253b_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_5253b_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_5253b_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_5253b_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_5253b_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5253b_level0_row0" class="row_heading level0 row0" >index</th>
#       <td id="T_5253b_row0_col0" class="data row0 col0" >200.000000</td>
#       <td id="T_5253b_row0_col1" class="data row0 col1" >100.500000</td>
#       <td id="T_5253b_row0_col2" class="data row0 col2" >57.879185</td>
#       <td id="T_5253b_row0_col3" class="data row0 col3" >1.000000</td>
#       <td id="T_5253b_row0_col4" class="data row0 col4" >50.750000</td>
#       <td id="T_5253b_row0_col5" class="data row0 col5" >100.500000</td>
#       <td id="T_5253b_row0_col6" class="data row0 col6" >150.250000</td>
#       <td id="T_5253b_row0_col7" class="data row0 col7" >200.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5253b_level0_row1" class="row_heading level0 row1" >TV</th>
#       <td id="T_5253b_row1_col0" class="data row1 col0" >200.000000</td>
#       <td id="T_5253b_row1_col1" class="data row1 col1" >147.042500</td>
#       <td id="T_5253b_row1_col2" class="data row1 col2" >85.854236</td>
#       <td id="T_5253b_row1_col3" class="data row1 col3" >0.700000</td>
#       <td id="T_5253b_row1_col4" class="data row1 col4" >74.375000</td>
#       <td id="T_5253b_row1_col5" class="data row1 col5" >149.750000</td>
#       <td id="T_5253b_row1_col6" class="data row1 col6" >218.825000</td>
#       <td id="T_5253b_row1_col7" class="data row1 col7" >296.400000</td>
#     </tr>
#     <tr>
#       <th id="T_5253b_level0_row2" class="row_heading level0 row2" >Radio</th>
#       <td id="T_5253b_row2_col0" class="data row2 col0" >200.000000</td>
#       <td id="T_5253b_row2_col1" class="data row2 col1" >23.264000</td>
#       <td id="T_5253b_row2_col2" class="data row2 col2" >14.846809</td>
#       <td id="T_5253b_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_5253b_row2_col4" class="data row2 col4" >9.975000</td>
#       <td id="T_5253b_row2_col5" class="data row2 col5" >22.900000</td>
#       <td id="T_5253b_row2_col6" class="data row2 col6" >36.525000</td>
#       <td id="T_5253b_row2_col7" class="data row2 col7" >49.600000</td>
#     </tr>
#     <tr>
#       <th id="T_5253b_level0_row3" class="row_heading level0 row3" >Newspaper</th>
#       <td id="T_5253b_row3_col0" class="data row3 col0" >200.000000</td>
#       <td id="T_5253b_row3_col1" class="data row3 col1" >30.554000</td>
#       <td id="T_5253b_row3_col2" class="data row3 col2" >21.778621</td>
#       <td id="T_5253b_row3_col3" class="data row3 col3" >0.300000</td>
#       <td id="T_5253b_row3_col4" class="data row3 col4" >12.750000</td>
#       <td id="T_5253b_row3_col5" class="data row3 col5" >25.750000</td>
#       <td id="T_5253b_row3_col6" class="data row3 col6" >45.100000</td>
#       <td id="T_5253b_row3_col7" class="data row3 col7" >114.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5253b_level0_row4" class="row_heading level0 row4" >Sales</th>
#       <td id="T_5253b_row4_col0" class="data row4 col0" >200.000000</td>
#       <td id="T_5253b_row4_col1" class="data row4 col1" >14.022500</td>
#       <td id="T_5253b_row4_col2" class="data row4 col2" >5.217457</td>
#       <td id="T_5253b_row4_col3" class="data row4 col3" >1.600000</td>
#       <td id="T_5253b_row4_col4" class="data row4 col4" >10.375000</td>
#       <td id="T_5253b_row4_col5" class="data row4 col5" >12.900000</td>
#       <td id="T_5253b_row4_col6" class="data row4 col6" >17.400000</td>
#       <td id="T_5253b_row4_col7" class="data row4 col7" >27.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **CORRELATION HEAMTMAP FOR NUMERICAL DATA**

# %%
numerical_columns = df.select_dtypes(include=['number']).columns
numerical_df = df[numerical_columns]
correlation_matrix = numerical_df.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap (Numerical Columns)')
plt.show()

# %% [markdown]
# **DISTRIBUTION OF INDEX**

# %%
for column in numerical_columns:
    fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(18, 4))
    sns.histplot(df[column], kde=False, color='skyblue', ax=ax1)
    ax1.set_title(f'Distribution of {column}')
    ax1.set_ylabel('Frequency')
    sns.boxplot(x=df[column], color='lightgreen', ax=ax2)
    ax2.set_title(f'Boxplot of {column}')
    if df[column].skew() > 1:
        df[column+'_log'] = np.log1p(df[column])
        sns.histplot(df[column+'_log'], kde=False, color='orange', ax=ax3)
        ax3.set_title(f'Log-transformed Distribution of {column}')
    else:
        ax3.set_title(f'Log-transformed plot not necessary for {column}')
        ax3.axis('off')
        
    plt.tight_layout()
    plt.show()

# %% [markdown]
# **PAIR PLOTS OF NUMERICAL COLUMNS**

# %%
def scatter_plots(df, numerical_columns):
    num_cols = len(numerical_columns)
    fig, axes = plt.subplots(num_cols, num_cols, figsize=(16, 16))
    for i in range(num_cols):
        for j in range(num_cols):
            if i != j:
                sns.scatterplot(ax=axes[i, j], x=df[numerical_columns[i]], y=df[numerical_columns[j]])
                axes[i, j].set_title(f'{numerical_columns[i]} vs {numerical_columns[j]}')
                axes[i, j].set_xlabel(numerical_columns[i])
                axes[i, j].set_ylabel(numerical_columns[j])
            else:
                axes[i, j].axis('off')
    plt.tight_layout()
    plt.show()
def pair_plots(df, numerical_columns):
    pair_plot = sns.pairplot(df[numerical_columns])
    pair_plot.fig.suptitle('Pair Plots of Numerical Columns', y=1.02)
    plt.tight_layout()
    plt.show()
scatter_plots(df, numerical_columns)
pair_plots(df, numerical_columns)

# %% [markdown]
# **SHAPE INFORMATION**

# %%
x=df[["TV","Radio","Newspaper"]]
y=df["Sales"]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=0.2)
print("THE SHAPES ARE AS FOLLOW:")
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# THE SHAPES ARE AS FOLLOW:
# (160, 3) (40, 3) (160,) (40,)
